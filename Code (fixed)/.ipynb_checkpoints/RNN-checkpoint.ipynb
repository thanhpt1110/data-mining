# %% [markdown]
# # RNN Model

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Đọc Dataset và chia data thành 2 bộ train và test

# %%
# Đọc dữ liệu từ file CSV, lấy các cột cần thiết và phân tích cột 'Date' làm chỉ mục
df = pd.read_csv('../Data/gld_price_data.csv', index_col='Date', parse_dates=True, usecols=['Date','GLD', 'USO', 'SLV','EUR/USD'])
# df.sort_values(by='Date', ascending=True, inplace=True)
# df.reset_index(inplace=True)

# Loại bỏ các dòng có giá trị thiếu (NaN) trong dữ liệu
df = df.dropna()

# Tách dữ liệu thành train_data và test_data theo tỉ lệ 80:20
train_data, test_data = train_test_split(df, test_size=0.2, shuffle=False)

# In kích thước của tập dữ liệu huấn luyện
print('Shape of data train', train_data.shape)

# In kích thước của tập dữ liệu kiểm tra
print('Shape of data test', test_data.shape)

# Tách biến mục tiêu 'GLD' từ tập dữ liệu huấn luyện
y_train = train_data['GLD']
y_test = test_data['GLD']

# Tách các biến đầu vào (features) từ tập dữ liệu huấn luyện, loại bỏ cột 'GLD'
X_train = train_data.drop(columns=['GLD'])
X_test = test_data.drop(columns=['GLD'])
# Out:
# Shape of data train (1832, 5)
# Shape of data test (458, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   datetime64[ns]
#  1   GLD      2290 non-null   float64
#  2   USO      2290 non-null   float64
#  3   SLV      2290 non-null   float64
#  4   EUR/USD  2290 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 89.6 KB

# %% [markdown]
# ### 3. Dataset overview

# %%
# Thiết lập kích thước biểu đồ với chiều rộng full (ví dụ 15 inch)
plt.figure(figsize=(15, 6), dpi=150)

# Vẽ biểu đồ cho tập huấn luyện (train)
plt.plot(train_data['GLD'], label='Train Data')

# Vẽ biểu đồ cho tập kiểm tra (test)
plt.plot(test_data['GLD'], label='Test Data')

# Thêm tiêu đề và nhãn
plt.title('Gold Price - Train & Test Data')
plt.xlabel('Date')
plt.ylabel('Gold Price')

# Chú thích
plt.legend()

# Hiển thị biểu đồ
plt.grid(color='white')
plt.show()

# %% [markdown]
# ### 4. Thông tin chi tiết của tập Train và Test

# %%
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1832 entries, 0 to 1831
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     1832 non-null   datetime64[ns]
#  1   GLD      1832 non-null   float64
#  2   USO      1832 non-null   float64
#  3   SLV      1832 non-null   float64
#  4   EUR/USD  1832 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 85.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, 1832 to 2289
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     458 non-null    datetime64[ns]
#  1   GLD      458 non-null    float64
#  2   USO      458 non-null    float64
#  3   SLV      458 non-null    float64
#  4   EUR/USD  458 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 21.5 KB

# %% [markdown]
# ## 5. Khởi tạo và huấn luyện mô hình RNN

# %%
from keras.layers import SimpleRNN, Dense, Dropout, Input
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from keras.layers import SimpleRNN, Dense, Dropout
#       2 from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
#       3 from sklearn.preprocessing import MinMaxScaler
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\api\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\api\activations\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\activations\__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import celu
#       4 from keras.src.activations.activations import elu
#       5 from keras.src.activations.activations import exponential
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\activations\activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\backend\__init__.py:10
#       7     import torch
#       9 from keras.src.api_export import keras_export
# ---> 10 from keras.src.backend.common.dtypes import result_type
#      11 from keras.src.backend.common.keras_tensor import KerasTensor
#      12 from keras.src.backend.common.keras_tensor import any_symbolic_tensors
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\backend\common\__init__.py:2
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#       4 from keras.src.backend.common.variables import Variable as KerasVariable
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\backend\common\dtypes.py:5
#       3 from keras.src.api_export import keras_export
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#       8 INT_TYPES = (
#       9     "uint8",
#      10     "uint16",
#    (...)
#      16     "int64",
#      17 )
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\backend\common\variables.py:12
#      10 from keras.src.backend.common.stateless_scope import in_stateless_scope
#      11 from keras.src.utils.module_utils import tensorflow as tf
# ---> 12 from keras.src.utils.naming import auto_name
#      15 class Variable:
#      16     """Represents a backend-agnostic variable in Keras.
#      17
#      18     A `Variable` acts as a container for state. It holds a tensor value and can
#    (...)
#      86     ```
#      87     """
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\utils\__init__.py:1
# ----> 1 from keras.src.utils.audio_dataset_utils import audio_dataset_from_directory
#       2 from keras.src.utils.dataset_utils import split_dataset
#       3 from keras.src.utils.file_utils import get_file
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\utils\audio_dataset_utils.py:4
#       1 import numpy as np
#       3 from keras.src.api_export import keras_export
# ----> 4 from keras.src.utils import dataset_utils
#       5 from keras.src.utils.module_utils import tensorflow as tf
#       6 from keras.src.utils.module_utils import tensorflow_io as tfio
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\utils\dataset_utils.py:9
#       5 from multiprocessing.pool import ThreadPool
#       7 import numpy as np
# ----> 9 from keras.src import tree
#      10 from keras.src.api_export import keras_export
#      11 from keras.src.utils import io_utils
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\tree\__init__.py:1
# ----> 1 from keras.src.tree.tree_api import assert_same_paths
#       2 from keras.src.tree.tree_api import assert_same_structure
#       3 from keras.src.tree.tree_api import flatten
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\tree\tree_api.py:6
#       3 from keras.src.utils.module_utils import optree
#       5 if optree.available:
# ----> 6     from keras.src.tree import optree_impl as tree_impl
#       7 elif dmtree.available:
#       8     from keras.src.tree import dmtree_impl as tree_impl
#
# File D:\PyCharm\Project\venv\Lib\site-packages\keras\src\tree\optree_impl.py:17
#      15 # Register backend-specific node classes
#      16 if backend() == "tensorflow":
# ---> 17     from tensorflow.python.trackable.data_structures import ListWrapper
#      19     optree.register_pytree_node(
#      20         ListWrapper,
#      21         lambda x: (x, None),
#      22         lambda metadata, children: ListWrapper(list(children)),
#      23         namespace="keras",
#      24     )
#      26     from tensorflow.python.trackable.data_structures import _DictWrapper
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['GLD']])

# %%
import numpy as np
# Số bước thời gian đầu vào
lookback = 60

# Chuẩn bị dữ liệu cho RNN
X = []
y = []

# Xây dựng các chuỗi đầu vào (input sequences) dựa trên `lookback` 
for i in range(lookback, len(scaled_data)):
    X.append(scaled_data[i-lookback:i, 0])  # Lấy 60 bước thời gian trước đó
    y.append(scaled_data[i, 0])  # Giá trị tiếp theo làm mục tiêu

X, y = np.array(X), np.array(y)

# Reshape dữ liệu thành (samples, time_steps, features) cho RNN
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
# Tách dữ liệu thành tập huấn luyện và kiểm tra
train_size = int(X.shape[0] * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
from keras.models import Sequential
# Xây dựng mô hình RNN
model = Sequential()

# Thêm lớp Input để xác định hình dạng đầu vào
model.add(Input(shape=(lookback, 1)))

# Thêm các lớp RNN và Dropout
model.add(SimpleRNN(units=50, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(SimpleRNN(units=50, activation='tanh', return_sequences=False))
model.add(Dropout(0.2))

# Thêm lớp đầu ra
model.add(Dense(units=1))  # Dự đoán một giá trị (giá vàng tiếp theo)

# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Hiển thị cấu trúc mô hình
model.summary()
# Out:
# C:\Users\HHunTTer\.conda\envs\lab-data-mining\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Huấn luyện mô hình
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.2091 - val_loss: 0.0041
# Epoch 2/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0329 - val_loss: 6.1567e-04
# Epoch 3/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0172 - val_loss: 0.0016
# Epoch 4/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0124 - val_loss: 0.0011
# Epoch 5/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0091 - val_loss: 8.8617e-04
# Epoch 6/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0073 - val_loss: 3.1838e-04
# Epoch 7/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0070 - val_loss: 3.8970e-04
# Epoch 8/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0058 - val_loss: 3.5868e-04
# Epoch 9/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0052 - val_loss: 2.0747e-04
# Epoch 10/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0045 - val_loss: 9.7433e-04
# Epoch 11/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0047 - val_loss: 3.9174e-04
# Epoch 12/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0048 - val_loss: 1.7659e-04
# Epoch 13/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0039 - val_loss: 1.3264e-04
# Epoch 14/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0038 - val_loss: 4.6569e-04
# Epoch 15/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0034 - val_loss: 3.4753e-04
# Epoch 16/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0034 - val_loss: 1.5535e-04
# Epoch 17/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035 - val_loss: 3.9021e-04
# Epoch 18/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0031 - val_loss: 1.1983e-04
# Epoch 19/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0028 - val_loss: 2.3408e-04
# Epoch 20/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0027 - val_loss: 1.9685e-04
# Epoch 21/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0025 - val_loss: 1.1154e-04
# Epoch 22/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0025 - val_loss: 9.8300e-04
# Epoch 23/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - val_loss: 1.0585e-04
# Epoch 24/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - val_loss: 1.2300e-04
# Epoch 25/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - val_loss: 1.2733e-04
# Epoch 26/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - val_loss: 1.4633e-04
# Epoch 27/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0022 - val_loss: 2.3502e-04
# Epoch 28/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0020 - val_loss: 9.9996e-05
# Epoch 29/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019 - val_loss: 1.0565e-04
# Epoch 30/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 9.6280e-05
# Epoch 31/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - val_loss: 2.0583e-04
# Epoch 32/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 1.0407e-04
# Epoch 33/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 1.6184e-04
# Epoch 34/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 2.0775e-04
# Epoch 35/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 1.0315e-04
# Epoch 36/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - val_loss: 9.9502e-05
# Epoch 37/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 1.0566e-04
# Epoch 38/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 2.7467e-04
# Epoch 39/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 1.7515e-04
# Epoch 40/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 2.7239e-04
# Epoch 41/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 9.5180e-05
# Epoch 42/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - val_loss: 1.6124e-04
# Epoch 43/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - val_loss: 9.5265e-05
# Epoch 44/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - val_loss: 9.3708e-05
# Epoch 45/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - val_loss: 1.1007e-04
# Epoch 46/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 1.3783e-04
# Epoch 47/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - val_loss: 1.2003e-04
# Epoch 48/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 2.1652e-04
# Epoch 49/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - val_loss: 1.4342e-04
# Epoch 50/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - val_loss: 1.2268e-04
# Epoch 51/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 1.1842e-04
# Epoch 52/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 2.3178e-04
# Epoch 53/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 1.1637e-04
# Epoch 54/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 8.6791e-05
# Epoch 55/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.1708e-04 - val_loss: 8.6216e-05
# Epoch 56/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0010 - val_loss: 1.5120e-04
# Epoch 57/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 1.0043e-04
# Epoch 58/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 9.8802e-05
# Epoch 59/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 8.7310e-05
# Epoch 60/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.6986e-04 - val_loss: 1.8183e-04
# Epoch 61/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0010 - val_loss: 1.4760e-04
# Epoch 62/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.4463e-04 - val_loss: 8.8629e-05
# Epoch 63/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.8550e-04 - val_loss: 1.5606e-04
# Epoch 64/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.9799e-04 - val_loss: 1.1009e-04
# Epoch 65/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.5315e-04 - val_loss: 1.2173e-04
# Epoch 66/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.3374e-04 - val_loss: 9.2488e-05
# Epoch 67/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.3962e-04 - val_loss: 1.0737e-04
# Epoch 68/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0010 - val_loss: 8.2146e-05
# Epoch 69/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.0440e-04 - val_loss: 8.7609e-05
# Epoch 70/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.4974e-04 - val_loss: 8.3730e-05
# Epoch 71/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0756e-04 - val_loss: 1.0832e-04
# Epoch 72/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.6788e-04 - val_loss: 1.4353e-04
# Epoch 73/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.1523e-04 - val_loss: 8.8106e-05
# Epoch 74/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.8238e-04 - val_loss: 2.4267e-04
# Epoch 75/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.2955e-04 - val_loss: 1.0383e-04
# Epoch 76/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 8.2509e-05
# Epoch 77/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4573e-04 - val_loss: 9.2652e-05
# Epoch 78/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.9114e-04 - val_loss: 9.4265e-05
# Epoch 79/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.7989e-04 - val_loss: 1.6560e-04
# Epoch 80/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4599e-04 - val_loss: 8.6149e-05
# Epoch 81/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.8819e-04 - val_loss: 2.6306e-04
# Epoch 82/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.6215e-04 - val_loss: 9.6998e-05
# Epoch 83/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.4081e-04 - val_loss: 7.9274e-05
# Epoch 84/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.2749e-04 - val_loss: 8.4289e-05
# Epoch 85/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.4200e-04 - val_loss: 8.4007e-05
# Epoch 86/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.4048e-04 - val_loss: 1.7249e-04
# Epoch 87/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.1492e-04 - val_loss: 1.0565e-04
# Epoch 88/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.1898e-04 - val_loss: 8.2209e-05
# Epoch 89/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.9744e-04 - val_loss: 9.1630e-05
# Epoch 90/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.0042e-04 - val_loss: 9.0387e-05
# Epoch 91/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.5556e-04 - val_loss: 8.8771e-05
# Epoch 92/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.8162e-04 - val_loss: 1.0836e-04
# Epoch 93/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.8623e-04 - val_loss: 7.9812e-05
# Epoch 94/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.8219e-04 - val_loss: 8.2418e-05
# Epoch 95/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.9717e-04 - val_loss: 2.1783e-04
# Epoch 96/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.9839e-04 - val_loss: 9.1397e-05
# Epoch 97/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1468e-04 - val_loss: 1.0674e-04
# Epoch 98/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.2110e-04 - val_loss: 8.3717e-05
# Epoch 99/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.9762e-04 - val_loss: 7.8177e-05
# Epoch 100/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.7272e-04 - val_loss: 8.9923e-05
# Epoch 101/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4140e-04 - val_loss: 7.9992e-05
# Epoch 102/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.4888e-04 - val_loss: 7.7642e-05
# Epoch 103/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.4945e-04 - val_loss: 1.1818e-04
# Epoch 104/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.2259e-04 - val_loss: 7.8220e-05
# Epoch 105/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4033e-04 - val_loss: 1.0115e-04
# Epoch 106/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.7241e-04 - val_loss: 9.5180e-05
# Epoch 107/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.6828e-04 - val_loss: 1.0100e-04
# Epoch 108/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.3578e-04 - val_loss: 7.9624e-05
# Epoch 109/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.7775e-04 - val_loss: 1.7863e-04
# Epoch 110/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.7908e-04 - val_loss: 8.0294e-05
# Epoch 111/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.7351e-04 - val_loss: 1.3019e-04
# Epoch 112/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4383e-04 - val_loss: 2.8565e-04
# Epoch 113/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1614e-04 - val_loss: 8.1213e-05
# Epoch 114/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.0366e-04 - val_loss: 1.0951e-04
# Epoch 115/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4986e-04 - val_loss: 3.3641e-04
# Epoch 116/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3453e-04 - val_loss: 9.1404e-05
# Epoch 117/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.7107e-04 - val_loss: 9.1939e-05
# Epoch 118/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.0132e-04 - val_loss: 8.8776e-05
# Epoch 119/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.2003e-04 - val_loss: 1.4331e-04
# Epoch 120/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.0124e-04 - val_loss: 1.0722e-04
# Epoch 121/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.9011e-04 - val_loss: 7.8157e-05
# Epoch 122/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.5184e-04 - val_loss: 8.3258e-05
# Epoch 123/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4765e-04 - val_loss: 8.2871e-05
# Epoch 124/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.7690e-04 - val_loss: 8.9255e-05
# Epoch 125/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.0857e-04 - val_loss: 1.1023e-04
# Epoch 126/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.4114e-04 - val_loss: 8.1870e-05
# Epoch 127/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2164e-04 - val_loss: 9.2035e-05
# Epoch 128/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.2763e-04 - val_loss: 1.1053e-04
# Epoch 129/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.6939e-04 - val_loss: 1.7240e-04
# Epoch 130/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3584e-04 - val_loss: 8.6155e-05
# Epoch 131/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.2515e-04 - val_loss: 9.3547e-05
# Epoch 132/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.0053e-04 - val_loss: 8.7404e-05
# Epoch 133/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.7656e-04 - val_loss: 8.6524e-05
# Epoch 134/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.6641e-04 - val_loss: 1.0663e-04
# Epoch 135/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.7062e-04 - val_loss: 1.1144e-04
# Epoch 136/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.6816e-04 - val_loss: 8.1915e-05
# Epoch 137/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.6450e-04 - val_loss: 9.4781e-05
# Epoch 138/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4947e-04 - val_loss: 1.5383e-04
# Epoch 139/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.5703e-04 - val_loss: 8.6493e-05
# Epoch 140/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.0333e-04 - val_loss: 1.4540e-04
# Epoch 141/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9060e-04 - val_loss: 8.7593e-05
# Epoch 142/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.3917e-04 - val_loss: 7.9721e-05
# Epoch 143/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.7931e-04 - val_loss: 1.1171e-04
# Epoch 144/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.7862e-04 - val_loss: 8.3018e-05
# Epoch 145/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.3029e-04 - val_loss: 1.1293e-04
# Epoch 146/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.0502e-04 - val_loss: 8.8664e-05
# Epoch 147/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.2567e-04 - val_loss: 9.2618e-05
# Epoch 148/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.2318e-04 - val_loss: 9.0989e-05
# Epoch 149/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.7335e-04 - val_loss: 1.1455e-04
# Epoch 150/150
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.5243e-04 - val_loss: 7.5602e-05

# %%
# Dự đoán trên tập kiểm tra
predicted_prices = model.predict(X_test)
#predicted_prices = scaler.inverse_transform(predicted_prices)

# Giải mã giá trị thực tế
#real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Đảo ngược chuẩn hóa cho y_test
y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Đảo ngược chuẩn hóa cho predicted_prices
predictions_rescaled = scaler.inverse_transform(predicted_prices).flatten()

# %%
# Tính toán các chỉ số đánh giá

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_rescaled, predictions_rescaled)

# Mean Absolute Percentage Error (MAPE)
mape = mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled) * 100 

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test_rescaled, predictions_rescaled))

# R-squared (R²)
r2 = r2_score(y_test_rescaled, predictions_rescaled)

print(f"MAE: {mae}")
print(f"MAPE: {mape}%")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 0.728001143341202
# RMSE: 0.9963554992091782
# MAPE: 0.005993197076121469%
# Accuracy: 99.99400680292388%

# %%
plt.figure(figsize=(15, 6), dpi=150)

sequence_length = 60

# Đảo ngược chuẩn hóa cho y_train
y_train_rescaled = scaler.inverse_transform(y_train.reshape(-1, 1)).flatten()

# Sau đó vẽ lại dữ liệu huấn luyện
plt.plot(df.index[lookback:train_size + lookback], y_train_rescaled, color='black', lw=2, label='Dữ liệu huấn luyện')

# Vẽ dữ liệu thực tế từ tập kiểm tra
plt.plot(df.index[train_size + lookback:], y_test_rescaled, label='Dữ liệu thực tế', color='blue')

# Vẽ dữ liệu dự đoán
plt.plot(df.index[train_size + lookback:], predictions_rescaled, label='Dữ liệu dự đoán', color='red')

# Thêm tiêu đề, nhãn, và chú thích
plt.title('Hiệu suất mô hình dự đoán giá vàng với RNN', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.grid(True)
plt.legend(['Dữ liệu huấn luyện', 'Dữ liệu thực tế', 'Dữ liệu dự đoán'], prop={'size': 15})

# Hiển thị biểu đồ
plt.show()
