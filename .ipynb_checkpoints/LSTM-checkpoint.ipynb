# %% [markdown]
# # LSTM

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Đọc Dataset và chia data thành 2 bộ train và test

# %%
# Đọc dữ liệu từ file CSV, lấy các cột cần thiết và phân tích cột 'Date' làm chỉ mục
df = pd.read_csv('gld_price_data.csv', index_col='Date', parse_dates=True, usecols=['Date','GLD', 'USO', 'SLV','EUR/USD'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(inplace=True)

# Loại bỏ các dòng có giá trị thiếu (NaN) trong dữ liệu
df = df.dropna()

# Tách dữ liệu thành train_data và test_data theo tỉ lệ 80:20
train_data, test_data = train_test_split(df, test_size=0.2, shuffle=False)

# In kích thước của tập dữ liệu huấn luyện
print('Shape of data train', train_data.shape)

# In kích thước của tập dữ liệu kiểm tra
print('Shape of data test', test_data.shape)

# Tách biến mục tiêu 'GLD' từ tập dữ liệu huấn luyện
y_train = train_data['GLD']
y_test = test_data['GLD']

# Tách các biến đầu vào (features) từ tập dữ liệu huấn luyện, loại bỏ cột 'GLD'
X_train = train_data.drop(columns=['GLD'])
X_test = test_data.drop(columns=['GLD'])
# Out:
# Shape of data train (1832, 5)
# Shape of data test (458, 5)

# %% [markdown]
# ## 3. Dataset overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   datetime64[ns]
#  1   GLD      2290 non-null   float64
#  2   USO      2290 non-null   float64
#  3   SLV      2290 non-null   float64
#  4   EUR/USD  2290 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 89.6 KB

# %%
# Thiết lập kích thước biểu đồ với chiều rộng full (ví dụ 15 inch)
plt.figure(figsize=(15, 6), dpi=150)

# Vẽ biểu đồ cho tập huấn luyện (train)
plt.plot(train_data['Date'], y_train, label='Train Data')

# Vẽ biểu đồ cho tập kiểm tra (test)
plt.plot(test_data['Date'], y_test, label='Test Data')

# Thêm tiêu đề và nhãn
plt.title('Gold Price - Train & Test Data')
plt.xlabel('Date')
plt.ylabel('Gold Price')

# Chú thích
plt.legend()

# Hiển thị biểu đồ
plt.grid(color='white')
plt.show()

# %% [markdown]
# ## 4. Thông tin chi tiết của tập Train và Test

# %%
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1832 entries, 0 to 1831
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     1832 non-null   datetime64[ns]
#  1   GLD      1832 non-null   float64
#  2   USO      1832 non-null   float64
#  3   SLV      1832 non-null   float64
#  4   EUR/USD  1832 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 85.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, 1832 to 2289
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     458 non-null    datetime64[ns]
#  1   GLD      458 non-null    float64
#  2   USO      458 non-null    float64
#  3   SLV      458 non-null    float64
#  4   EUR/USD  458 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 21.5 KB

# %% [markdown]
# ## 5. Khởi tạo và huấn luyện mô hình LSTM

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt

# %%
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['GLD']])

# %%
# Tạo hàm chia dữ liệu thành chuỗi
def create_sequences(data, target_index, sequence_length):
    sequences = []
    labels = []
    for i in range(len(data) - sequence_length):
        sequences.append(data[i:i + sequence_length])
        labels.append(data[i + sequence_length, target_index])
    return np.array(sequences), np.array(labels)

# %%
# Thiết lập tham số
sequence_length = 10
target_index = df.columns.get_loc('GLD') - 1  # Vị trí cột 'GLD' trong scaled_data
train_scaled = scaled_data[:len(train_data)]
test_scaled = scaled_data[len(train_data):]

# %%
# Tạo tập train và test
X_train, y_train = create_sequences(train_scaled, target_index, sequence_length)
X_test, y_test = create_sequences(test_scaled, target_index, sequence_length)

# %%
# Xây dựng mô hình LSTM
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# C:\Users\ASUS\anaconda3\envs\THDataMining\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Huấn luyện mô hình
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0754 - val_loss: 5.4623e-04
# Epoch 2/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - val_loss: 4.4260e-04
# Epoch 3/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3921e-04 - val_loss: 4.2246e-04
# Epoch 4/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - val_loss: 4.1794e-04
# Epoch 5/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3455e-04 - val_loss: 4.2329e-04
# Epoch 6/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9252e-04 - val_loss: 4.1836e-04
# Epoch 7/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7551e-04 - val_loss: 4.9152e-04
# Epoch 8/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2971e-04 - val_loss: 4.8422e-04
# Epoch 9/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0736e-04 - val_loss: 4.2557e-04
# Epoch 10/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7521e-04 - val_loss: 3.9233e-04
# Epoch 11/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9503e-04 - val_loss: 4.3476e-04
# Epoch 12/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5664e-04 - val_loss: 4.2315e-04
# Epoch 13/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7061e-04 - val_loss: 4.2139e-04
# Epoch 14/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1189e-04 - val_loss: 3.7060e-04
# Epoch 15/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5847e-04 - val_loss: 4.2004e-04
# Epoch 16/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0172e-04 - val_loss: 3.6014e-04
# Epoch 17/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1385e-04 - val_loss: 3.8771e-04
# Epoch 18/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5849e-04 - val_loss: 3.5780e-04
# Epoch 19/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6823e-04 - val_loss: 3.6814e-04
# Epoch 20/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9833e-04 - val_loss: 3.2048e-04
# Epoch 21/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7680e-04 - val_loss: 3.1834e-04
# Epoch 22/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8505e-04 - val_loss: 3.4580e-04
# Epoch 23/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9068e-04 - val_loss: 4.0710e-04
# Epoch 24/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3632e-04 - val_loss: 2.9323e-04
# Epoch 25/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2273e-04 - val_loss: 2.9491e-04
# Epoch 26/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8568e-04 - val_loss: 2.7304e-04
# Epoch 27/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9588e-04 - val_loss: 2.7323e-04
# Epoch 28/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1491e-04 - val_loss: 2.7048e-04
# Epoch 29/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0776e-04 - val_loss: 3.7561e-04
# Epoch 30/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8335e-04 - val_loss: 4.7450e-04
# Epoch 31/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6273e-04 - val_loss: 2.4460e-04
# Epoch 32/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2089e-04 - val_loss: 4.7077e-04
# Epoch 33/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2227e-04 - val_loss: 2.7676e-04
# Epoch 34/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8322e-04 - val_loss: 2.4098e-04
# Epoch 35/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8089e-04 - val_loss: 2.5322e-04
# Epoch 36/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7265e-04 - val_loss: 2.5886e-04
# Epoch 37/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2968e-04 - val_loss: 2.1200e-04
# Epoch 38/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1613e-04 - val_loss: 2.0497e-04
# Epoch 39/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5696e-04 - val_loss: 2.9446e-04
# Epoch 40/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9180e-04 - val_loss: 2.3561e-04
# Epoch 41/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5708e-04 - val_loss: 2.0451e-04
# Epoch 42/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2143e-04 - val_loss: 2.9946e-04
# Epoch 43/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5312e-04 - val_loss: 2.4225e-04
# Epoch 44/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3587e-04 - val_loss: 1.9763e-04
# Epoch 45/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.1242e-04 - val_loss: 1.8388e-04
# Epoch 46/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6488e-04 - val_loss: 2.3884e-04
# Epoch 47/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5117e-04 - val_loss: 2.3660e-04
# Epoch 48/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5087e-04 - val_loss: 1.7951e-04
# Epoch 49/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6245e-04 - val_loss: 1.8944e-04
# Epoch 50/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8674e-04 - val_loss: 2.6254e-04
# Epoch 51/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8798e-04 - val_loss: 1.7962e-04
# Epoch 52/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8833e-04 - val_loss: 1.6935e-04
# Epoch 53/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3393e-04 - val_loss: 1.6041e-04
# Epoch 54/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8086e-04 - val_loss: 1.6872e-04
# Epoch 55/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4946e-04 - val_loss: 1.6384e-04
# Epoch 56/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5821e-04 - val_loss: 1.5807e-04
# Epoch 57/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8111e-04 - val_loss: 1.6736e-04
# Epoch 58/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4854e-04 - val_loss: 1.5485e-04
# Epoch 59/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3548e-04 - val_loss: 1.4861e-04
# Epoch 60/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8150e-04 - val_loss: 1.7124e-04
# Epoch 61/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3422e-04 - val_loss: 1.9603e-04
# Epoch 62/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4101e-04 - val_loss: 1.4777e-04
# Epoch 63/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7712e-04 - val_loss: 1.4384e-04
# Epoch 64/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2150e-04 - val_loss: 1.5365e-04
# Epoch 65/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0683e-04 - val_loss: 1.4281e-04
# Epoch 66/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6357e-04 - val_loss: 2.2181e-04
# Epoch 67/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4565e-04 - val_loss: 1.6271e-04
# Epoch 68/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3162e-04 - val_loss: 1.3977e-04
# Epoch 69/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8341e-04 - val_loss: 1.7692e-04
# Epoch 70/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.3706e-04 - val_loss: 1.5366e-04
# Epoch 71/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0815e-04 - val_loss: 1.3015e-04
# Epoch 72/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2853e-04 - val_loss: 1.7203e-04
# Epoch 73/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7995e-04 - val_loss: 1.7925e-04
# Epoch 74/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.0158e-04 - val_loss: 1.4447e-04
# Epoch 75/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.1262e-04 - val_loss: 1.2708e-04
# Epoch 76/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5300e-04 - val_loss: 1.3167e-04
# Epoch 77/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4547e-04 - val_loss: 1.8137e-04
# Epoch 78/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3217e-04 - val_loss: 1.3536e-04
# Epoch 79/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6088e-04 - val_loss: 1.2576e-04
# Epoch 80/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8183e-04 - val_loss: 2.6045e-04
# Epoch 81/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3021e-04 - val_loss: 1.4290e-04
# Epoch 82/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8183e-04 - val_loss: 1.4933e-04
# Epoch 83/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6613e-04 - val_loss: 1.3025e-04
# Epoch 84/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7755e-04 - val_loss: 1.4586e-04
# Epoch 85/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0364e-04 - val_loss: 1.1977e-04
# Epoch 86/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7370e-04 - val_loss: 1.3483e-04
# Epoch 87/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7574e-04 - val_loss: 1.2174e-04
# Epoch 88/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5439e-04 - val_loss: 1.1920e-04
# Epoch 89/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5355e-04 - val_loss: 1.8291e-04
# Epoch 90/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9566e-04 - val_loss: 1.6073e-04
# Epoch 91/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5349e-04 - val_loss: 1.5910e-04
# Epoch 92/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5268e-04 - val_loss: 1.5934e-04
# Epoch 93/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8182e-04 - val_loss: 1.1759e-04
# Epoch 94/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2316e-04 - val_loss: 1.1760e-04
# Epoch 95/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3972e-04 - val_loss: 1.2977e-04
# Epoch 96/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6433e-04 - val_loss: 1.4288e-04
# Epoch 97/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7908e-04 - val_loss: 1.1510e-04
# Epoch 98/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4877e-04 - val_loss: 1.2038e-04
# Epoch 99/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2648e-04 - val_loss: 1.6501e-04
# Epoch 100/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8102e-04 - val_loss: 1.2915e-04
# Epoch 101/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6167e-04 - val_loss: 1.3730e-04
# Epoch 102/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4855e-04 - val_loss: 1.1537e-04
# Epoch 103/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3000e-04 - val_loss: 1.3307e-04
# Epoch 104/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3444e-04 - val_loss: 1.1598e-04
# Epoch 105/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5766e-04 - val_loss: 1.1385e-04
# Epoch 106/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2831e-04 - val_loss: 1.2026e-04
# Epoch 107/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2482e-04 - val_loss: 1.2938e-04
# Epoch 108/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3345e-04 - val_loss: 1.1653e-04
# Epoch 109/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2983e-04 - val_loss: 1.4938e-04
# Epoch 110/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5722e-04 - val_loss: 1.5720e-04
# Epoch 111/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7950e-04 - val_loss: 1.3690e-04
# Epoch 112/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6844e-04 - val_loss: 1.3964e-04
# Epoch 113/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3654e-04 - val_loss: 1.1667e-04
# Epoch 114/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4531e-04 - val_loss: 1.1571e-04
# Epoch 115/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3852e-04 - val_loss: 1.1250e-04
# Epoch 116/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6781e-04 - val_loss: 1.2075e-04
# Epoch 117/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1306e-04 - val_loss: 1.6245e-04
# Epoch 118/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8142e-04 - val_loss: 1.3122e-04
# Epoch 119/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4111e-04 - val_loss: 1.5748e-04
# Epoch 120/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5161e-04 - val_loss: 1.2712e-04
# Epoch 121/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3792e-04 - val_loss: 1.4545e-04
# Epoch 122/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6174e-04 - val_loss: 1.2805e-04
# Epoch 123/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4975e-04 - val_loss: 1.3401e-04
# Epoch 124/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6874e-04 - val_loss: 1.1650e-04
# Epoch 125/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3221e-04 - val_loss: 1.0941e-04
# Epoch 126/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9037e-04 - val_loss: 1.0928e-04
# Epoch 127/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4833e-04 - val_loss: 1.1114e-04
# Epoch 128/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2556e-04 - val_loss: 1.3363e-04
# Epoch 129/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4541e-04 - val_loss: 1.2728e-04
# Epoch 130/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3098e-04 - val_loss: 1.1027e-04
# Epoch 131/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1710e-04 - val_loss: 1.0974e-04
# Epoch 132/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5894e-04 - val_loss: 1.2570e-04
# Epoch 133/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5373e-04 - val_loss: 1.4008e-04
# Epoch 134/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7727e-04 - val_loss: 1.5952e-04
# Epoch 135/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4476e-04 - val_loss: 1.4026e-04
# Epoch 136/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3691e-04 - val_loss: 1.6180e-04
# Epoch 137/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4645e-04 - val_loss: 1.3650e-04
# Epoch 138/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5298e-04 - val_loss: 1.0737e-04
# Epoch 139/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4561e-04 - val_loss: 1.1970e-04
# Epoch 140/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1917e-04 - val_loss: 1.1698e-04
# Epoch 141/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6287e-04 - val_loss: 1.0891e-04
# Epoch 142/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4848e-04 - val_loss: 1.3955e-04
# Epoch 143/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7822e-04 - val_loss: 1.1186e-04
# Epoch 144/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6475e-04 - val_loss: 1.4886e-04
# Epoch 145/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0387e-04 - val_loss: 1.0877e-04
# Epoch 146/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3527e-04 - val_loss: 1.1704e-04
# Epoch 147/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4982e-04 - val_loss: 1.3268e-04
# Epoch 148/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6300e-04 - val_loss: 1.1887e-04
# Epoch 149/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4754e-04 - val_loss: 1.1088e-04
# Epoch 150/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1137e-04 - val_loss: 1.1400e-04

# %%
# Dự đoán trên tập test
predictions = model.predict(X_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Tạo cột giả với các giá trị 0 có kích thước phù hợp với predictions
dummy_features = np.zeros((predictions.shape[0], scaled_data.shape[1] - 1))

# Nối cột dự đoán vào cột giả
predictions_rescaled = scaler.inverse_transform(
    np.hstack([dummy_features, predictions])
)[:, -1]

# Tương tự cho y_test
dummy_features_test = np.zeros((y_test.shape[0], scaled_data.shape[1] - 1))

y_test_rescaled = scaler.inverse_transform(
    np.hstack([dummy_features_test, y_test.reshape(-1, 1)])
)[:, -1]

# %%
# Tính toán các chỉ số
rmse = np.sqrt(mean_squared_error(y_test_rescaled, predictions_rescaled))
mape = mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled) * 100
mae = mean_absolute_error(y_test_rescaled, predictions_rescaled)

print(f"RMSE: {rmse}")
print(f"MAPE: {mape}%")
print(f"MAE: {mae}")
# Out:
# RMSE: 1.1684252895724618
# MAPE: 0.7410938434986392%
# MAE: 0.9007167986782333

# %%
plt.figure(figsize=(15, 6))

# Nếu dữ liệu đã được chuẩn hóa, cần chuyển ngược lại về giá trị gốc
y_train_rescaled = scaler.inverse_transform(y_train.reshape(-1, 1))
# Sau đó vẽ lại dữ liệu huấn luyện
plt.plot(train_data['Date'][sequence_length:], y_train_rescaled, color='black', lw=2, label='Training Data')

# Vẽ dữ liệu thực tế (test set)
plt.plot(test_data['Date'], test_data['GLD'], label='Dữ liệu thực tế', color='blue')

# Vẽ dữ liệu dự đoán (dùng sequence_length để căn chỉnh)
plt.plot(test_data['Date'][sequence_length:], predictions_rescaled, label='Dữ liệu dự đoán', color='red')

# Thêm tiêu đề và nhãn
plt.title('Training Data, Actual and Predicted')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)

# Hiển thị legend
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(y_test_rescaled, label='Thực tế (Actual)', color='blue')
plt.plot(predictions_rescaled, label='Dự đoán (Predicted)', color='red')
plt.legend()
plt.title('Thực tế vs Dự đoán')
plt.show()

# %%
plt.hist(y_test_rescaled, bins=30, alpha=0.7, label='Thực tế')
plt.hist(predictions_rescaled, bins=30, alpha=0.7, label='Dự đoán')
plt.legend()
plt.title('Phân phối Thực tế vs Dự đoán')
plt.show()
