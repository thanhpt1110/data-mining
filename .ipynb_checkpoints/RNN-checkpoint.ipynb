# %%
{
  "cells": [],
  "metadata": {},
  "nbformat": 4,
  "nbformat_minor": 4
}
# Out:
# {'cells': [], 'metadata': {}, 'nbformat': 4, 'nbformat_minor': 4}

# %% [markdown]
# # RNN

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Đọc Dataset và chia data thành 2 bộ train và test

# %%
# Đọc dữ liệu từ file CSV, lấy các cột cần thiết và phân tích cột 'Date' làm chỉ mục
df = pd.read_csv('./Data/gld_price_data.csv', index_col='Date', parse_dates=True, usecols=['Date','GLD', 'USO', 'SLV','EUR/USD'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(inplace=True)

# Loại bỏ các dòng có giá trị thiếu (NaN) trong dữ liệu
df = df.dropna()

# Tách dữ liệu thành train_data và test_data theo tỉ lệ 80:20
train_data, test_data = train_test_split(df, test_size=0.2, shuffle=False)

# In kích thước của tập dữ liệu huấn luyện
print('Shape of data train', train_data.shape)

# In kích thước của tập dữ liệu kiểm tra
print('Shape of data test', test_data.shape)

# Tách biến mục tiêu 'GLD' từ tập dữ liệu huấn luyện
y_train = train_data['GLD']
y_test = test_data['GLD']

# Tách các biến đầu vào (features) từ tập dữ liệu huấn luyện, loại bỏ cột 'GLD'
X_train = train_data.drop(columns=['GLD'])
X_test = test_data.drop(columns=['GLD'])
# Out:
# Shape of data train (1832, 5)
# Shape of data test (458, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   datetime64[ns]
#  1   GLD      2290 non-null   float64
#  2   USO      2290 non-null   float64
#  3   SLV      2290 non-null   float64
#  4   EUR/USD  2290 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 89.6 KB

# %%
# Thiết lập kích thước biểu đồ với chiều rộng full (ví dụ 15 inch)
plt.figure(figsize=(15, 6), dpi=150)

# Vẽ biểu đồ cho tập huấn luyện (train)
plt.plot(train_data['Date'], y_train, label='Train Data')

# Vẽ biểu đồ cho tập kiểm tra (test)
plt.plot(test_data['Date'], y_test, label='Test Data')

# Thêm tiêu đề và nhãn
plt.title('Gold Price - Train & Test Data')
plt.xlabel('Date')
plt.ylabel('Gold Price')

# Chú thích
plt.legend()

# Hiển thị biểu đồ
plt.grid(color='white')
plt.show()

# %%
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1832 entries, 0 to 1831
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     1832 non-null   datetime64[ns]
#  1   GLD      1832 non-null   float64
#  2   USO      1832 non-null   float64
#  3   SLV      1832 non-null   float64
#  4   EUR/USD  1832 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 85.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, 1832 to 2289
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     458 non-null    datetime64[ns]
#  1   GLD      458 non-null    float64
#  2   USO      458 non-null    float64
#  3   SLV      458 non-null    float64
#  4   EUR/USD  458 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 21.5 KB

# %% [markdown]
# ## 5. Khởi tạo và huấn luyện mô hình RNN

# %%
from keras.layers import SimpleRNN, Dense, Dropout, LSTM
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler

# %%
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['GLD']])

# %%
import numpy as np
# Số bước thời gian đầu vào
lookback = 60

# Chuẩn bị dữ liệu cho RNN
X = []
y = []

# Xây dựng các chuỗi đầu vào (input sequences) dựa trên `lookback` 
for i in range(lookback, len(scaled_data)):
    X.append(scaled_data[i-lookback:i, 0])  # Lấy 60 bước thời gian trước đó
    y.append(scaled_data[i, 0])  # Giá trị tiếp theo làm mục tiêu

X, y = np.array(X), np.array(y)

# Reshape dữ liệu thành (samples, time_steps, features) cho RNN
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
# Tách dữ liệu thành tập huấn luyện và kiểm tra
train_size = int(X.shape[0] * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
from keras.models import Sequential
# Xây dựng mô hình RNN
model = Sequential()

# Thêm một lớp RNN
model.add(SimpleRNN(units=50, activation='tanh', return_sequences=True, input_shape=(lookback, 1)))
model.add(Dropout(0.2))
model.add(SimpleRNN(units=50, activation='tanh', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))  # Dự đoán một giá trị (giá vàng tiếp theo)

# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# C:\Users\ASUS\anaconda3\envs\THDataMining\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Huấn luyện mô hình
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2003 - val_loss: 0.0018
# Epoch 2/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0238 - val_loss: 0.0032
# Epoch 3/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0169 - val_loss: 6.0969e-04
# Epoch 4/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0126 - val_loss: 2.9338e-04
# Epoch 5/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0090 - val_loss: 4.4551e-04
# Epoch 6/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0088 - val_loss: 0.0021
# Epoch 7/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 2.4122e-04
# Epoch 8/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 9/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0061 - val_loss: 1.6702e-04
# Epoch 10/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0055 - val_loss: 1.5497e-04
# Epoch 11/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0048 - val_loss: 1.5219e-04
# Epoch 12/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0044 - val_loss: 8.1983e-04
# Epoch 13/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0044 - val_loss: 6.7777e-04
# Epoch 14/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 15/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0039 - val_loss: 5.2461e-04
# Epoch 16/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0041 - val_loss: 1.2647e-04
# Epoch 17/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0036 - val_loss: 3.2693e-04
# Epoch 18/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0033 - val_loss: 1.2579e-04
# Epoch 19/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0030 - val_loss: 1.2215e-04
# Epoch 20/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0031 - val_loss: 1.1020e-04
# Epoch 21/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0033 - val_loss: 2.3502e-04
# Epoch 22/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0026 - val_loss: 1.5529e-04
# Epoch 23/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0025 - val_loss: 1.0588e-04
# Epoch 24/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0027 - val_loss: 1.8931e-04
# Epoch 25/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0026 - val_loss: 4.1346e-04
# Epoch 26/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0026 - val_loss: 1.0450e-04
# Epoch 27/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0022 - val_loss: 1.1307e-04
# Epoch 28/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0023 - val_loss: 1.0492e-04
# Epoch 29/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0021 - val_loss: 3.9862e-04
# Epoch 30/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0021 - val_loss: 2.4020e-04
# Epoch 31/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0020 - val_loss: 9.7346e-05
# Epoch 32/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019 - val_loss: 8.2451e-04
# Epoch 33/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0024 - val_loss: 1.4199e-04
# Epoch 34/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 1.2560e-04
# Epoch 35/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0017 - val_loss: 2.8328e-04
# Epoch 36/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 2.9433e-04
# Epoch 37/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 1.8238e-04
# Epoch 38/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019 - val_loss: 1.4207e-04
# Epoch 39/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018 - val_loss: 2.9189e-04
# Epoch 40/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018 - val_loss: 1.1205e-04
# Epoch 41/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0020 - val_loss: 1.1906e-04
# Epoch 42/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - val_loss: 1.0145e-04
# Epoch 43/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0016 - val_loss: 2.9706e-04
# Epoch 44/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0016 - val_loss: 4.1406e-04
# Epoch 45/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019 - val_loss: 4.2127e-04
# Epoch 46/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0017 - val_loss: 1.0974e-04
# Epoch 47/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0013 - val_loss: 1.2504e-04
# Epoch 48/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0013 - val_loss: 1.0706e-04
# Epoch 49/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 1.4066e-04
# Epoch 50/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - val_loss: 3.4002e-04

# %%
# Dự đoán trên tập kiểm tra
predicted_prices = model.predict(X_test)
#predicted_prices = scaler.inverse_transform(predicted_prices)

# Giải mã giá trị thực tế
#real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step

# %%
# Đảo ngược chuẩn hóa cho y_test
y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Đảo ngược chuẩn hóa cho predicted_prices
predictions_rescaled = scaler.inverse_transform(predicted_prices).flatten()

# %%
# Tính toán các chỉ số đánh giá
mae = mean_absolute_error(y_test_rescaled, predictions_rescaled)
rmse = np.sqrt(mean_squared_error(y_test_rescaled, predictions_rescaled))
mape = mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled)

print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
print(f"MAPE: {mape}%")
# Out:
# MAE: 1.868427072410139
# RMSE: 2.1130076547035785
# MAPE: 0.015425726486822484%

# %%
plt.figure(figsize=(15, 6))

sequence_length = 60


# Đảo ngược chuẩn hóa cho y_train
y_train_rescaled = scaler.inverse_transform(y_train.reshape(-1, 1)).flatten()

# Sau đó vẽ lại dữ liệu huấn luyện
plt.plot(df['Date'][lookback:train_size + lookback], y_train_rescaled, color='black', lw=2, label='Training Data')

# Vẽ dữ liệu thực tế từ tập kiểm tra
plt.plot(df['Date'][train_size + lookback:], y_test_rescaled, label='Dữ liệu thực tế', color='blue')

# Vẽ dữ liệu dự đoán
plt.plot(df['Date'][train_size + lookback:], predictions_rescaled, label='Dữ liệu dự đoán', color='red')

# Thêm tiêu đề, nhãn, và chú thích
plt.title('Gold Price: Training, Actual, and Predicted Data')
plt.xlabel('Date')
plt.ylabel('Gold Price')
plt.grid(True)
plt.legend()

# Hiển thị biểu đồ
plt.show()
