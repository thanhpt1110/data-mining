# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# __In this notebook, we are going to build a time series model to predict the future price of gold, which can be very useful for traders. For this purpose, we use the historical gold price data for 10 years (from 2013 to 2023).__

# %% [markdown]
# ### Let's get started:

# %% [markdown]
# # Step 1: Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import SimpleRNN

# %% [markdown]
# # Step 2: Reading Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/DoAn/gld_price_data.csv')

# %% [markdown]
# # Step 3: Dataset Overview

# %%
df
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %% [markdown]
# __As you can see, the data set includes daily gold price information including daily Open, High and Low prices and the final price of each day (Price) along with the volume of transactions and price changes in each day.__

# %% [markdown]
# __Dataset Basic Information:__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %% [markdown]
# __All variables are stored as object.__

# %% [markdown]
# # Step 4: Data Preparation

# %% [markdown]
# ## Step 4.1: Feature Subset Selection
# __Not have feature should have been droped__

# %% [markdown]
# ## Step 4.2: Transforming Data

# %% [markdown]
# __Date feature is stored as object in the data frame. To increase the speed of calculations, we convert it's data type to datetime and then sort this feature in ascending order:__

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# __The " , " sign is redundant in the dataset. First, we remove it from the entire dataset and then change the data type of the numerical variables to float:__

# %%
NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].replace({',': ''}, regex=True)
df[NumCols] = df[NumCols].astype('float64')

# %% [markdown]
# __Result:__

# %%
df.head()
# Out:
#         Date          SPX        GLD        USO     SLV   EUR/USD
# 0 2008-01-02  1447.160034  84.860001  78.470001  15.180  1.471692
# 1 2008-01-03  1447.160034  85.570000  78.370003  15.285  1.474491
# 2 2008-01-04  1411.630005  85.129997  77.309998  15.167  1.475492
# 3 2008-01-07  1416.180054  84.769997  75.500000  15.053  1.468299
# 4 2008-01-08  1390.189941  86.779999  76.059998  15.590  1.557099

# %% [markdown]
# ## Step 4.3: Checking Duplicates
# __There are no duplicate samples in Date feature:__

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Step 4.4: Checking Missing Values
# __There are no missing values in the dataset:__

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Step 5: Visualizing Gold Price History Data
#
# __Interactive Gold Price Chart:__

# %%
fig = px.line(y=df.GLD, x=df.Date)
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Date",
                  yaxis_title="Scaled Price",
                  title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(255,223,0,0.8)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7c984649-cbd9-430a-8d45-4c3241ce49bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c984649-cbd9-430a-8d45-4c3241ce49bd")) {                    Plotly.newPlot(                        "7c984649-cbd9-430a-8d45-4c3241ce49bd",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2008-01-02T00:00:00","2008-01-03T00:00:00","2008-01-04T00:00:00","2008-01-07T00:00:00","2008-01-08T00:00:00","2008-01-09T00:00:00","2008-01-10T00:00:00","2008-01-11T00:00:00","2008-01-14T00:00:00","2008-01-15T00:00:00","2008-01-16T00:00:00","2008-01-17T00:00:00","2008-01-18T00:00:00","2008-01-22T00:00:00","2008-01-23T00:00:00","2008-01-24T00:00:00","2008-01-25T00:00:00","2008-01-28T00:00:00","2008-01-29T00:00:00","2008-01-30T00:00:00","2008-01-31T00:00:00","2008-02-01T00:00:00","2008-02-04T00:00:00","2008-02-05T00:00:00","2008-02-06T00:00:00","2008-02-07T00:00:00","2008-02-08T00:00:00","2008-02-11T00:00:00","2008-02-12T00:00:00","2008-02-13T00:00:00","2008-02-14T00:00:00","2008-02-15T00:00:00","2008-02-19T00:00:00","2008-02-20T00:00:00","2008-02-21T00:00:00","2008-02-22T00:00:00","2008-02-25T00:00:00","2008-02-26T00:00:00","2008-02-27T00:00:00","2008-02-28T00:00:00","2008-02-29T00:00:00","2008-03-03T00:00:00","2008-03-04T00:00:00","2008-03-05T00:00:00","2008-03-06T00:00:00","2008-03-07T00:00:00","2008-03-10T00:00:00","2008-03-11T00:00:00","2008-03-12T00:00:00","2008-03-13T00:00:00","2008-03-14T00:00:00","2008-03-17T00:00:00","2008-03-18T00:00:00","2008-03-19T00:00:00","2008-03-20T00:00:00","2008-03-24T00:00:00","2008-03-25T00:00:00","2008-03-26T00:00:00","2008-03-27T00:00:00","2008-03-28T00:00:00","2008-04-01T00:00:00","2008-04-02T00:00:00","2008-04-03T00:00:00","2008-04-07T00:00:00","2008-04-08T00:00:00","2008-04-09T00:00:00","2008-04-10T00:00:00","2008-04-14T00:00:00","2008-04-15T00:00:00","2008-04-16T00:00:00","2008-04-17T00:00:00","2008-04-21T00:00:00","2008-04-22T00:00:00","2008-04-23T00:00:00","2008-04-24T00:00:00","2008-04-28T00:00:00","2008-04-29T00:00:00","2008-05-01T00:00:00","2008-05-05T00:00:00","2008-05-06T00:00:00","2008-05-07T00:00:00","2008-05-08T00:00:00","2008-05-12T00:00:00","2008-05-13T00:00:00","2008-05-14T00:00:00","2008-05-15T00:00:00","2008-05-19T00:00:00","2008-05-20T00:00:00","2008-05-21T00:00:00","2008-05-22T00:00:00","2008-05-27T00:00:00","2008-05-28T00:00:00","2008-05-29T00:00:00","2008-06-02T00:00:00","2008-06-03T00:00:00","2008-06-04T00:00:00","2008-06-05T00:00:00","2008-06-09T00:00:00","2008-06-10T00:00:00","2008-06-11T00:00:00","2008-06-12T00:00:00","2008-06-16T00:00:00","2008-06-17T00:00:00","2008-06-18T00:00:00","2008-06-19T00:00:00","2008-06-23T00:00:00","2008-06-24T00:00:00","2008-06-25T00:00:00","2008-06-26T00:00:00","2008-07-01T00:00:00","2008-07-02T00:00:00","2008-07-03T00:00:00","2008-07-07T00:00:00","2008-07-08T00:00:00","2008-07-09T00:00:00","2008-07-10T00:00:00","2008-07-14T00:00:00","2008-07-15T00:00:00","2008-07-16T00:00:00","2008-07-17T00:00:00","2008-07-21T00:00:00","2008-07-22T00:00:00","2008-07-23T00:00:00","2008-07-24T00:00:00","2008-07-28T00:00:00","2008-07-29T00:00:00","2008-07-30T00:00:00","2008-08-07T00:00:00","2008-08-25T00:00:00","2008-08-26T00:00:00","2008-08-27T00:00:00","2008-08-28T00:00:00","2008-09-02T00:00:00","2008-09-03T00:00:00","2008-09-04T00:00:00","2008-09-08T00:00:00","2008-09-09T00:00:00","2008-09-10T00:00:00","2008-09-11T00:00:00","2008-09-15T00:00:00","2008-09-16T00:00:00","2008-09-17T00:00:00","2008-09-18T00:00:00","2008-09-22T00:00:00","2008-09-23T00:00:00","2008-09-24T00:00:00","20 ...

# %% [markdown]
# # Step 6: Splitting Data to Training & Test Sets
# __Since we cannot train on future data in time series data, we should not divide the time series data randomly. In time series splitting, testing set is always later than training set. We consider the last year for testing and everything else for training:__

# %%
# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
train_data, test_data = train_test_split(df, test_size=0.2, shuffle=False)

# Số lượng mẫu trong tập kiểm tra
test_size = len(test_data)

# %% [markdown]
# __Gold Price Training and Test Sets Plot:__

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df.Date[:-test_size], df.GLD[:-test_size], color='black', lw=2)
plt.plot(df.Date[-test_size:], df.GLD[-test_size:], color='blue', lw=2)
plt.title('Gold Price Training and Test Sets', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %% [markdown]
# # Step 7: Data Scaling
# __Since we aim to predict Price only based on its historical data, we scale Price using MinMaxScaler to avoid intensive computations:__

# %%
scaler = MinMaxScaler()
scaler.fit(df.GLD.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %% [markdown]
# # Step 8: Restructure Data & Create Sliding Window
# __The use of prior time steps to predict the next time step is called sliding window. In this way, time series data can be expressed as supervised learning. We can do this by using previous time steps as input variables and use the next time step as the output variable. The number of previous time steps is called the window width. Here we set window width to 60. Therefore, X_train and X_test will be nested lists containing lists of 60 time-stamp prices. y_train and y_test are also lists of gold prices containing the next day's gold price corresponds to each list in X_train and X_test respectively:__

# %%
window_size = 60

# %% [markdown]
# __Training Set:__

# %%
train_data = df.GLD[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %% [markdown]
# __Test Set:__

# %%
test_data = df.GLD[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %% [markdown]
# # Step 9: Converting Data to Numpy Arrays
#
# __Now X_train and X_test are nested lists (two-dimensional lists) and y_train is a one-dimensional list. We need to convert them to numpy arrays with a higher dimension, which is the data format accepted by TensorFlow when training the neural network:__

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (1772, 60, 1)
# y_train Shape:  (1772, 1)
# X_test Shape:   (458, 60, 1)
# y_test Shape:   (458, 1)

# %% [markdown]
# # Step 10: Creating an RNN Network

# %% [markdown]
# __Model Definition:__

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = SimpleRNN(units = 16, return_sequences=True)(input1)
    x = Dropout(0.2)(x)
    x = SimpleRNN(units = 32, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = SimpleRNN(units = 128)(x)
    x = Dropout(0.2)(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.summary()

    return model

# %% [markdown]
# __Model Training:__

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 60, 1)]           0
#
#  simple_rnn (SimpleRNN)      (None, 60, 16)            288
#
#  dropout (Dropout)           (None, 60, 16)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60, 32)            1568
#
#  dropout_1 (Dropout)         (None, 60, 32)            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 128)               20608
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 22593 (88.25 KB)
# Trainable params: 22593 (88.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/150
# 50/50 [==============================] - 8s 62ms/step - loss: 0.2035 - val_loss: 0.0085
# Epoch 2/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0886 - val_loss: 0.0025
# Epoch 3/150
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0599 - val_loss: 0.0015
# Epoch 4/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0401 - val_loss: 0.0036
# Epoch 5/150
# 50/50 [==============================] - 5s 95ms/step - loss: 0.0274 - val_loss: 0.0028
# Epoch 6/150
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0227 - val_loss: 0.0010
# Epoch 7/150
# 50/50 [==============================] - 2s 43ms/step - loss: 0.0163 - val_loss: 5.1148e-04
# Epoch 8/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0134 - val_loss: 3.9084e-04
# Epoch 9/150
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0131 - val_loss: 3.6297e-04
# Epoch 10/150
# 50/50 [==============================] - 3s 65ms/step - loss: 0.0099 - val_loss: 4.1999e-04
# Epoch 11/150
# 50/50 [==============================] - 4s 80ms/step - loss: 0.0089 - val_loss: 3.8232e-04
# Epoch 12/150
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0076 - val_loss: 2.8151e-04
# Epoch 13/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0068 - val_loss: 4.1813e-04
# Epoch 14/150
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0064 - val_loss: 7.2325e-04
# Epoch 15/150
# 50/50 [==============================] - 3s 54ms/step - loss: 0.0054 - val_loss: 2.3240e-04
# Epoch 16/150
# 50/50 [==============================] - 4s 77ms/step - loss: 0.0051 - val_loss: 8.2996e-04
# Epoch 17/150
# 50/50 [==============================] - 4s 75ms/step - loss: 0.0048 - val_loss: 3.1829e-04
# Epoch 18/150
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0050 - val_loss: 2.4708e-04
# Epoch 19/150
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0045 - val_loss: 3.1077e-04
# Epoch 20/150
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0040 - val_loss: 4.2101e-04
# Epoch 21/150
# 50/50 [==============================] - 4s 76ms/step - loss: 0.0037 - val_loss: 2.4620e-04
# Epoch 22/150
# 50/50 [==============================] - 3s 61ms/step - loss: 0.0037 - val_loss: 7.1261e-04
# Epoch 23/150
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0036 - val_loss: 2.5066e-04
# Epoch 24/150
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0032 - val_loss: 2.2382e-04
# Epoch 25/150
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0027 - val_loss: 2.3087e-04
# Epoch 26/150
# 50/50 [==============================] - 3s 69ms/step - loss: 0.0028 - val_loss: 4.9629e-04
# Epoch 27/150
# 50/50 [==============================] - 4s 70ms/step - loss: 0.0033 - val_loss: 5.3797e-04
# Epoch 28/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0032 - val_loss: 2.7493e-04
# Epoch 29/150
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0029 - val_loss: 3.7930e-04
# Epoch 30/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0031 - val_loss: 3.2383e-04
# Epoch 31/150
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0026 - val_loss: 2.8743e-04
# Epoch 32/150
# 50/50 [==============================] - 4s 78ms/step - loss: 0.0025 - val_loss: 2.2137e-04
# Epoch 33/150
# 50/50 [==============================] - 3s 67ms/step - loss: 0.0024 - val_loss: 2.4492e-04
# Epoch 34/150
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0025 - val_loss: 6.1828e-04
# Epoch 35/150
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0021 - val_loss: 3.0586e-04
# Epoch 36/150
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0022 - val_loss: 2.7054e-04
# Epoch 37/150
# 50/50 [==============================] - 4s 73ms/step - loss: 0.0020 - val_loss: 1.9028e-04
# Epoch 38/150
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0020 - val_loss: 2.0147e-04
# Epoch 39/150
# 50/50 [==============================] - 2s 43ms/step - loss: 0.0020 - val_loss: 3.1919e-04
# Epoch 40/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0023 - val_loss: 4.5751e-04
# Epoch 41/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0025 - val_loss: 5.2736e-04
# Epoch 42/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0022 - val_loss: 2.2989e-04
# Epoch 43/150
# 50/50 [==============================] - 5s 99ms/step - loss: 0.0020 - val_loss: 3.9494e-04
# Epoch 44/150
# 50/50 [==============================] - 3s 56ms/step - loss: 0.0018 - val_loss: 1.9462e-04
# Epoch 45/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0018 - val_loss: 4.1595e-04
# Epoch 46/150
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0022 - val_loss: 2.2619e-04
# Epoch 47/150
# 50/50 [==============================] - 2s 43ms/step - loss: 0.0018 - val_loss: 2.9376e-04
# Epoch 48/150
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0016 - val_loss: 2.4626e-04
# Epoch 49/150
# 50/50 [==============================] - 4s 83ms/step - loss: 0.0017 - val_loss: 1.7394e-04
# Epoch 50/150
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0017 - val_loss: 2.7782e-04
# Epoch 51/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0017 - val_loss: 3.1874e-04
# Epoch 52/150
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0017 - val_loss: 1.8316e-04
# Epoch 53/150
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0016 - val_loss: 1.9090e-04
# Epoch 54/150
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0016 - val_loss: 1.6486e-04
# Epoch 55/150
# 50/50 [==============================] - 3s 64ms/step - loss: 0.0017 - val_loss: 1.9076e-04
# Epoch 56/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0018 - val_loss: 4.8702e-04
# Epoch 57/150
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0017 - val_loss: 1.7100e-04
# Epoch 58/150
# 50/50 [==============================] - 2s 43ms/step - loss: 0.0015 - val_loss: 3.4088e-04
# Epoch 59/150
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0015 - val_loss: 2.0007e-04
# Epoch 60/150
# 50/50 [==============================] - 4s 71ms/step - loss: 0.0015 - val_loss: 1.6774e-04
# Epoch 61/150
# 50/50 [==============================] - 3s 64ms/step - loss: 0.0018 - val_loss: 3.8139e-04
# Epoch 62/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0016 - val_loss: 1.5716e-04
# Epoch 63/150
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0015 - val_loss: 2.3382e-04
# Epoch 64/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0015 - val_loss: 4.2154e-04
# Epoch 65/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0013 - val_loss: 1.6945e-04
# Epoch 66/150
# 50/50 [==============================] - 4s 75ms/step - loss: 0.0012 - val_loss: 2.3559e-04
# Epoch 67/150
# 50/50 [==============================] - 3s 64ms/step - loss: 0.0013 - val_loss: 3.2233e-04
# Epoch 68/150
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0014 - val_loss: 1.4846e-04
# Epoch 69/150
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0014 - val_loss: 1.7801e-04
# Epoch 70/150
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0013 - val_loss: 2.2037e-04
# Epoch 71/150
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0013 - val_loss: 1.8279e-04
# Epoch 72/150
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0014 - val_loss: 4.3864e-04
# Epoch 73/150
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0013 - val_loss: 2.6045e-04
# Epoch 74/150
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0013 - val_loss: 2.5365e-04
# Epoch 75/150
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0013 - val_loss: 1.8732e-04
# Epoch 76/150
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0013 - val_loss: 1.5265e-04
# Epoch 77/150
# 50/50 [==============================] - 4s 76ms/step - loss: 0.0017 - val_loss: 2.2156e-04
# Epoch 78/150
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0011 - val_loss: 2.5356e-04
# Epoch 79/150
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0011 - val_loss: 2.3210e-04
# Epoch 80/150
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0012 - val_loss: 2.2690e-04
# Epoch 81/150
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0012 - val_loss: 1.5567e-04
# Epoch 82/150
# 50/50 [==============================] - 4s 83ms/step - loss: 0.0012 - val_loss: 1.5888e-04
# Epoch 83/150
# 50/50 [==============================] - 4s 76ms/step - loss: 0.0013 - val_loss: 2.0197e-04
# Epoch 84/150
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0011 - val_loss: 1.4705e-04
# Epoch 85/150
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0011 - val_loss: 3.9718e-04
# Epoch 86/150
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0011 - val_loss: 1.6942e-04
# Epoch 87/150
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0013 - val_loss: 1.5088e-04
# Epoch 88/150
# 50/50 [==============================] - 4s 78ms/step - loss: 0.0011 - val_loss: 2.0063e-04
# Epoch 89/150
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0010 - val_loss: 3.6162e-04
# Epoch 90/150
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0012 - val_loss: 1.9422e-04
# Epoch 91/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0012 - val_loss: 3.0032e-04
# Epoch 92/150
# 50/50 [==============================] - 3s 50ms/step - loss: 0.0010 - val_loss: 1.4526e-04
# Epoch 93/150
# 50/50 [==============================] - 3s 63ms/step - loss: 0.0011 - val_loss: 1.7065e-04
# Epoch 94/150
# 50/50 [==============================] - 4s 75ms/step - loss: 0.0011 - val_loss: 4.7719e-04
# Epoch 95/150
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0012 - val_loss: 1.4909e-04
# Epoch 96/150
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0011 - val_loss: 1.7082e-04
# Epoch 97/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0010 - val_loss: 1.6336e-04
# Epoch 98/150
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0012 - val_loss: 1.6977e-04
# Epoch 99/150
# 50/50 [==============================] - 4s 76ms/step - loss: 0.0011 - val_loss: 1.4021e-04
# Epoch 100/150
# 50/50 [==============================] - 3s 65ms/step - loss: 9.8952e-04 - val_loss: 1.5903e-04
# Epoch 101/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0010 - val_loss: 1.5634e-04
# Epoch 102/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0010 - val_loss: 2.8798e-04
# Epoch 103/150
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0010 - val_loss: 2.0542e-04
# Epoch 104/150
# 50/50 [==============================] - 3s 53ms/step - loss: 0.0011 - val_loss: 1.5780e-04
# Epoch 105/150
# 50/50 [==============================] - 4s 85ms/step - loss: 0.0010 - val_loss: 1.7773e-04
# Epoch 106/150
# 50/50 [==============================] - 3s 51ms/step - loss: 0.0012 - val_loss: 1.3341e-04
# Epoch 107/150
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0012 - val_loss: 4.0634e-04
# Epoch 108/150
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0012 - val_loss: 1.3952e-04
# Epoch 109/150
# 50/50 [==============================] - 2s 48ms/step - loss: 8.7869e-04 - val_loss: 1.3168e-04
# Epoch 110/150
# 50/50 [==============================] - 3s 68ms/step - loss: 9.5942e-04 - val_loss: 2.2345e-04
# Epoch 111/150
# 50/50 [==============================] - 3s 68ms/step - loss: 9.5487e-04 - val_loss: 1.8187e-04
# Epoch 112/150
# 50/50 [==============================] - 2s 44ms/step - loss: 9.4968e-04 - val_loss: 1.7381e-04
# Epoch 113/150
# 50/50 [==============================] - 2s 48ms/step - loss: 7.9598e-04 - val_loss: 1.7297e-04
# Epoch 114/150
# 50/50 [==============================] - 2s 49ms/step - loss: 9.3425e-04 - val_loss: 3.2243e-04
# Epoch 115/150
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0012 - val_loss: 2.0087e-04
# Epoch 116/150
# 50/50 [==============================] - 4s 78ms/step - loss: 0.0010 - val_loss: 2.1635e-04
# Epoch 117/150
# 50/50 [==============================] - 3s 56ms/step - loss: 9.0789e-04 - val_loss: 1.4299e-04
# Epoch 118/150
# 50/50 [==============================] - 4s 81ms/step - loss: 9.1815e-04 - val_loss: 1.4014e-04
# Epoch 119/150
# 50/50 [==============================] - 6s 112ms/step - loss: 9.1877e-04 - val_loss: 1.6565e-04
# Epoch 120/150
# 50/50 [==============================] - 7s 146ms/step - loss: 9.5063e-04 - val_loss: 1.5185e-04
# Epoch 121/150
# 50/50 [==============================] - 3s 52ms/step - loss: 0.0010 - val_loss: 1.4961e-04
# Epoch 122/150
# 50/50 [==============================] - 2s 48ms/step - loss: 9.4651e-04 - val_loss: 2.2680e-04
# Epoch 123/150
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0011 - val_loss: 2.0471e-04
# Epoch 124/150
# 50/50 [==============================] - 3s 67ms/step - loss: 0.0010 - val_loss: 1.3048e-04
# Epoch 125/150
# 50/50 [==============================] - 4s 75ms/step - loss: 8.1398e-04 - val_loss: 1.3879e-04
# Epoch 126/150
# 50/50 [==============================] - 2s 49ms/step - loss: 9.9242e-04 - val_loss: 1.2641e-04
# Epoch 127/150
# 50/50 [==============================] - 2s 46ms/step - loss: 8.5767e-04 - val_loss: 2.0464e-04
# Epoch 128/150
# 50/50 [==============================] - 2s 48ms/step - loss: 9.4948e-04 - val_loss: 6.2435e-04
# Epoch 129/150
# 50/50 [==============================] - 2s 48ms/step - loss: 8.9218e-04 - val_loss: 1.7620e-04
# Epoch 130/150
# 50/50 [==============================] - 4s 80ms/step - loss: 8.6151e-04 - val_loss: 2.9168e-04
# Epoch 131/150
# 50/50 [==============================] - 3s 62ms/step - loss: 8.9195e-04 - val_loss: 1.4470e-04
# Epoch 132/150
# 50/50 [==============================] - 2s 50ms/step - loss: 8.8023e-04 - val_loss: 1.4385e-04
# Epoch 133/150
# 50/50 [==============================] - 2s 46ms/step - loss: 8.5813e-04 - val_loss: 1.3174e-04
# Epoch 134/150
# 50/50 [==============================] - 2s 47ms/step - loss: 7.7588e-04 - val_loss: 2.7222e-04
# Epoch 135/150
# 50/50 [==============================] - 3s 59ms/step - loss: 8.3808e-04 - val_loss: 1.5906e-04
# Epoch 136/150
# 50/50 [==============================] - 4s 86ms/step - loss: 8.0276e-04 - val_loss: 1.7257e-04
# Epoch 137/150
# 50/50 [==============================] - 2s 44ms/step - loss: 8.5541e-04 - val_loss: 1.7248e-04
# Epoch 138/150
# 50/50 [==============================] - 2s 46ms/step - loss: 0.0011 - val_loss: 1.3579e-04
# Epoch 139/150
# 50/50 [==============================] - 2s 48ms/step - loss: 8.5332e-04 - val_loss: 1.2833e-04
# Epoch 140/150
# 50/50 [==============================] - 2s 46ms/step - loss: 8.5707e-04 - val_loss: 1.3190e-04
# Epoch 141/150
# 50/50 [==============================] - 3s 68ms/step - loss: 8.2967e-04 - val_loss: 1.7821e-04
# Epoch 142/150
# 50/50 [==============================] - 4s 72ms/step - loss: 7.6698e-04 - val_loss: 1.7690e-04
# Epoch 143/150
# 50/50 [==============================] - 2s 50ms/step - loss: 9.0879e-04 - val_loss: 1.2963e-04
# Epoch 144/150
# 50/50 [==============================] - 3s 51ms/step - loss: 7.6767e-04 - val_loss: 1.2689e-04
# Epoch 145/150
# 50/50 [==============================] - 2s 46ms/step - loss: 9.3150e-04 - val_loss: 1.2703e-04
# Epoch 146/150
# 50/50 [==============================] - 3s 59ms/step - loss: 8.3327e-04 - val_loss: 2.0515e-04
# Epoch 147/150
# 50/50 [==============================] - 4s 76ms/step - loss: 8.6779e-04 - val_loss: 1.3730e-04
# Epoch 148/150
# 50/50 [==============================] - 3s 51ms/step - loss: 8.3183e-04 - val_loss: 1.3391e-04
# Epoch 149/150
# 50/50 [==============================] - 2s 46ms/step - loss: 9.9472e-04 - val_loss: 1.7313e-04
# Epoch 150/150
# 50/50 [==============================] - 2s 46ms/step - loss: 8.9942e-04 - val_loss: 1.9829e-04

# %% [markdown]
# # Step 11: Model Evaluation

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 15/15 [==============================] - 0s 23ms/step - loss: 1.7433e-04
# 15/15 [==============================] - 1s 23ms/step

# %%
MAE = mean_absolute_error(y_test, y_pred)
MAPE = mean_absolute_percentage_error(y_test, y_pred)
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
# Print evaluation metrics
print(f'MAE: {MAE}')
print(f'MAPE: {MAPE}')
print(f'RMSE: {RMSE}')
# Out:
# MAE: 0.010735504802137478
# MAPE: 0.024064480338757174
# RMSE: 0.013203332156782733

# %% [markdown]
# # Step 12: Visualizing Results

# %% [markdown]
# __Returning the actual and predicted Price values to their primary scale:__

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %% [markdown]
# __Investigating the closeness of the prices predicted by the model to the actual prices:__

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Model Performance on Gold Price Prediction with RNN', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
